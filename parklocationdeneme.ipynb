# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("park_location.csv")

# %%
df2=df.loc[df['COUNTY_NAME'] == "SARIYER"]

# %%
BBox = (df.LONGITUDE.min(),df.LONGITUDE.max(),df.LATITUDE.min(),df.LATITUDE.max())

# %%
BBox2 = (df2.LONGITUDE.min(),df2.LONGITUDE.max(),df2.LATITUDE.min(),df2.LATITUDE.max())

# %%
BBox2
# Out:
# (28.9761651938051, 29.1090956888875, 41.087562917708205, 41.2520626366439)

# %%
#ruh_m = plt.imread('C:/Users/doguk/Downloads/map.jpg')
ruh_m2 = plt.imread('map2.png')

# %% [markdown]
# Failed mapping attempt

# %%
fig, ax = plt.subplots(figsize=(17,11))
ax.scatter(df2.LONGITUDE, df2.LATITUDE, zorder=1,  c='b', s=0.5)
ax.set_title('Plotting ')
ax.set_xlim(BBox2[0],BBox2[1])
ax.set_ylim(BBox2[2],BBox[3])
ax.imshow(ruh_m2, zorder=0, extent = BBox2, aspect= 'equal')

# %%
ruh_m2
# Out:
# array([[[0.9529412 , 0.9411765 , 0.92156863, 1.        ],
#         [0.8862745 , 0.88235295, 0.8666667 , 1.        ],
#         [0.8039216 , 0.8       , 0.79607844, 1.        ],
#         ...,
#         [0.6666667 , 0.827451  , 0.8745098 , 1.        ],
#         [0.6666667 , 0.827451  , 0.8745098 , 1.        ],
#         [0.6666667 , 0.827451  , 0.8745098 , 1.        ]],
#
#        [[0.9490196 , 0.9372549 , 0.9137255 , 1.        ],
#         [0.95686275, 0.94509804, 0.9254902 , 1.        ],
#         [0.80784315, 0.80784315, 0.8       , 1.        ],
#         ...,
#         [0.6666667 , 0.827451  , 0.8745098 , 1.        ],
#         [0.6666667 , 0.827451  , 0.8745098 , 1.        ],
#         [0.6666667 , 0.827451  , 0.8745098 , 1.        ]],
#
#        [[0.9490196 , 0.9372549 , 0.9137255 , 1.        ],
#         [0.9490196 , 0.9372549 , 0.9137255 , 1.        ],
#         [0.8784314 , 0.8745098 , 0.8627451 , 1.        ],
#         ...,
# ...
